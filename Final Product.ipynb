# %%
#Import Dependencies
import pandas
from sqlalchemy import create_engine
from config import user_name, password

# %%
# SQL Alchemy
#engine = create_engine(f'postgresql://{user_name}:{password}@localhost:5432/Olympics')
#conn = engine.connect()
#Athlete = pd.read_sql('select * from athlete', conn)

# %%
rds_connection_string = "postgres:postgres@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# D:\Coding\anaconda\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2275         try:
# -> 2276             return fn()
#    2277         except dialect.dbapi.Error as e:
#
# D:\Coding\anaconda\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     362         if not self._use_threadlocal:
# --> 363             return _ConnectionFairy._checkout(self)
#     364
#
# D:\Coding\anaconda\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     772         if not fairy:
# --> 773             fairy = _ConnectionRecord.checkout(pool)
#     774
#
# D:\Coding\anaconda\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     491     def checkout(cls, pool):
# --> 492         rec = pool._do_get()
#     493         try:
#
# ...

# %%
olympics.to_sql(name='athlete', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-671252a4c619> in <module>
# ----> 1 olympics.to_sql(name='athlete', con=engine, if_exists='append', index=False)
#
# NameError: name 'olympics' is not defined
